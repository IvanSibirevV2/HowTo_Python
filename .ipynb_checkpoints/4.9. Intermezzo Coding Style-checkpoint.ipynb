# %% [markdown]
# https://docs.python.org/3/tutorial/index.html

# %% [markdown]
# _4.9. Intermezzo Coding Style

# %% [markdown]
# # 4.9. Интермеццо: Стиль кодирования¶

# %% [markdown]
# Теперь, когда вы собираетесь писать более длинные и сложные фрагменты Python, самое время поговорить о стиле кодирования. Большинство языков могут быть написаны (или более сжато отформатированы) в разных стилях; некоторые из них более удобочитаемы, чем другие. Сделать так, чтобы другим было легко читать ваш код, - это всегда хорошая идея, и принятие хорошего стиля кодирования чрезвычайно помогает в этом.

# %% [markdown]
# Для Python PEP 8 стал руководством по стилю, которого придерживается большинство проектов; он способствует очень удобочитаемому и приятному глазу стилю кодирования. Каждый разработчик Python должен когда-нибудь прочитать его; вот наиболее важные моменты, извлеченные для вас:

# %% [markdown]
# Используйте отступ в 4 пробела и никаких табуляций.

# %% [markdown]
# 4 пробела - хороший компромисс между небольшим отступом (позволяет увеличить глубину вложения) и большим отступом (легче читается). Табуляции вносят путаницу, и их лучше не использовать.

# %% [markdown]
# Переносите строки так, чтобы они не превышали 79 символов.

# %% [markdown]
# Это помогает пользователям с маленькими дисплеями и позволяет размещать несколько файлов кода бок о бок на больших дисплеях.

# %% [markdown]
# Используйте пустые строки для разделения функций и классов, а также более крупные блоки кода внутри функций.
#
# По возможности размещайте комментарии в отдельной строке.
#
# Используйте строки документации.
#
# Используйте пробелы вокруг операторов и после запятых, но не непосредственно внутри конструкций, заключающих в квадратные скобки: a = f(1, 2) + g(3, 4).
#
# Называйте свои классы и функции последовательно; соглашение заключается в том, чтобы использовать верхний регистр для классов и нижний регистр_with_underscores для функций и методов. Всегда используйте self в качестве имени для первого аргумента метода (подробнее о классах и методах смотрите в разделе "Первый взгляд на классы").
#
# Не используйте причудливые кодировки, если ваш код предназначен для использования в международных средах. В любом случае лучше всего работает стандарт Python, UTF-8 или даже обычный ASCII.
#
# Аналогично, не используйте символы, отличные от ASCII, в идентификаторах, если есть хотя бы малейший шанс, что люди, говорящие на другом языке, прочитают или поддержат код.

# %% [markdown]
# Сноски
#
# 1
# На самом деле, вызов по ссылке на объект был бы лучшим описанием, поскольку, если передается изменяемый объект, вызывающий увидит любые изменения, которые вызываемый объект вносит в него (элементы, вставленные в список).
#
# © Copyright 2001-2024, Python Software Foundation.
# Эта страница лицензирована по лицензии Python Software Foundation версии 2.
# Примеры, рецепты и другой код в документации дополнительно лицензируются по лицензии BSD с нулевым пунктом.
# Смотрите Историю и лицензию для получения дополнительной информации.
#
# Фонд программного обеспечения Python является некоммерческой корпорацией. Пожалуйста, сделайте пожертвование.
#
# Последнее обновление 20 января 2024 года (16:15 UTC). Обнаружена ошибка?
# Создано с использованием Sphinx 4.5.0.
