# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \begin{pmatrix}
# 1 & 0 & 1 & 0 & 1
# \\0 & 1 & 2 & 1 & 0
# \\1 & 2 & 0 & 2 & 1
# \\0 & 1 & 2 & 1 & 0
# \\1 & 0 & 1 & 0 & 1
# \end{pmatrix}
# $$
